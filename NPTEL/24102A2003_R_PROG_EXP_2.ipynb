# %% [markdown]
# ## Name: Chirag Chaudhari
# ## Roll no: 24102A2003
# ## Branch: CMPN-A

# %% [markdown]
# ## Assignment and Combining Data

# %%
x=20
y<-"Chirag"
my_vector<-c(1,2,3,4,5)
print(x)
print(y)
print(my_vector)
#print()
# Out:
# [1] 20
# [1] "Chirag"
# [1] 1 2 3 4 5

# %% [markdown]
# ## Identifying Data types

# %%
is.numeric(x)
is.numeric(y)
is.character(x)
is.character(y)
# Out:
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] TRUE

# %% [markdown]
# ## Converting Data types

# %%
a = 20
is.numeric(x)
b = as.character(x)
is.numeric(b)
is.character(b)
print(b)
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] "20"

# %% [markdown]
# ## Checking Modes

# %%
n1<-100
storage.mode(n1)
n2<-1.1
storage.mode(n2)
str<-"apple"
storage.mode(str)
my_vector2<-c(1,2,3,4,5)
storage.mode(my_vector2)
# Out:
# [1] "double"
# [1] "double"
# [1] "character"
# [1] "double"

# %% [markdown]
# ## Scaler Calculations and BODMAS

# %%
print(3-2)
2*5
(((2+3)*5 + 5) - 10)/2
ans = 3/0
print(ans)
is.infinite(ans)
# Out:
# [1] 1
# [1] 10
# [1] 10
# [1] Inf
# [1] TRUE

# %% [markdown]
# ## Vector and Scalar Calculations

# %%
c(2,3,5,7) + 10
c(12,13,15,17) - 10
c(2,3,5,7) * 10
c(12,13,15,17) / 10
# Out:
# [1] 12 13 15 17
# [1] 2 3 5 7
# [1] 20 30 50 70
# [1] 1.2 1.3 1.5 1.7

# %% [markdown]
# ## Calculations Between Two Data Vectors

# %%
c(2,3,5,7) + c(-2,-3,-5,8)
c(2,3,5,7) - c(-2,-3,-5,8)
c(2,3,5,7) * c(-2,-3,-5,8)
c(24,20,8,16) / c(3,4,2,8)
# Out:
# [1]  0  0  0 15
# [1]  4  6 10 -1
# [1]  -4  -9 -25  56
# [1] 8 5 4 2

# %% [markdown]
# ## Vectors of unequal lenghts

# %%
c(24,20,8,16) / c(4,2) #Multiples
c(2,3,5,7) * c(8,9,10) #Non-multiples
# Out:
# [1]  6 10  2  8
# Warning message in c(2, 3, 5, 7) * c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 16 27 50 56
